# %%
import os
import json

# Function to read all JSON files in a given folder
def read_json_files(folder_path):
    json_data = {}
    
    # Loop through all files in the folder
    for filename in os.listdir(folder_path):
        # Check if the file has a .json extension
        if filename.endswith('.json'):
            file_path = os.path.join(folder_path, filename)
            # Open and load the JSON file
            with open(file_path, 'r') as file:
                try:
                    data = json.load(file)
                    json_data[filename] = data
                except json.JSONDecodeError as e:
                    print(f"Error reading {filename}: {e}")
    
    return json_data

# %%
folder_path = '/Users/user/Documents/GitHub/EldenRing-GraphRAG/data_input'
json_files = read_json_files(folder_path)

# Print the content of all JSON files
for filename, data in json_files.items():
    print(f"Contents of {filename}:")
    print(json.dumps(data, indent=4))
# Out:
# Contents of locations.json:
# [
#     {
#         "id": "17f69c5a795l0i2m72bjeqbh713r3o",
#         "name": "Bridge Of Sacrifice",
#         "image": "https://eldenring.fanapis.com/images/locations/17f69c5a795l0i2m72bjeqbh713r3o.png",
#         "region": "Limgrave",
#         "description": "A busy bridge swarming with iron-clad foes. Be prepared to engage in an array of melee, ranged and artillery attacks or attempt to push past them"
#     },
#     {
#         "id": "17f69869a3bl0i2m72p0sbjub568ch",
#         "name": "Church Of Elleh",
#         "image": "https://eldenring.fanapis.com/images/locations/17f69869a3bl0i2m72p0sbjub568ch.png",
#         "region": "Limgrave",
#         "description": "Church of Elleh is a ruined building that hides a Site of Grace. The rooftop has caved in and offers no protection from the elements, and weeds are overtaking the walls, but this doesn't stop merchants from seeking what little shelter is on offer"
#     },
#     {
# ...

# %%
# Print the content of all JSON files
for filename, data in json_files.items():
    # print(f"Contents of {filename}:")
    print(json.dumps(data, indent=4))

# %%
import pandas as pd

# %%
path = '/Users/user/Documents/GitHub/EldenRing-GraphRAG/data_input/locations.json'
df = pd.read_json(path)
df.drop(columns=['id', 'image', 'Liurnia of the Lakes'], inplace=True)
df.dropna(inplace=True)

# %%
path = '/Users/user/Documents/GitHub/EldenRing-GraphRAG/data_input/ammos.json'
df = pd.read_json(path)
df.drop(columns=['id', 'image', 'type', 'attackPower', 'passive'], inplace=True)
df.dropna(inplace=True)

# %%
path = '/Users/user/Documents/GitHub/EldenRing-GraphRAG/data_input/armors.json'
df = pd.read_json(path)
df.info()
df.drop(columns=['id', 'image', 'category', 'dmgNegation', 'resistance', 'weight'], inplace=True)
df.dropna(inplace=True)

# %%
path = '/Users/user/Documents/GitHub/EldenRing-GraphRAG/data_input/ashes.json'
df = pd.read_json(path)
df.head()
df.drop(columns=['id', 'image', 'affinity', 'skill'], inplace=True)
df.dropna(inplace=True)

# %%
path = '/Users/user/Documents/GitHub/EldenRing-GraphRAG/data_input/bosses.json'
df = pd.read_json(path)
# df.head()
df.drop(columns=['id', 'image', 'region', 'drops', 'location', 'healthPoints'], inplace=True)
df.dropna(inplace=True)

# %%
path = '/Users/user/Documents/GitHub/EldenRing-GraphRAG/data_input/classes.json'
df = pd.read_json(path)
df.head()
df.drop(columns=['id', 'image', 'stats'], inplace=True)
df.dropna(inplace=True)

# %%
path = '/Users/user/Documents/GitHub/EldenRing-GraphRAG/data_input/creatures.json'
df = pd.read_json(path)
df.head()
df.drop(columns=['id', 'image', 'location', 'drops'], inplace=True)
df.dropna(inplace=True)

# %%
path = '/Users/user/Documents/GitHub/EldenRing-GraphRAG/data_input/incantations.json'
df = pd.read_json(path)
df.head()
df.drop(columns=['id', 'image', 'type', 'cost', 'slots', 'description', 'requires'], inplace=True)
df.dropna(inplace=True)

# %%
path = '/Users/user/Documents/GitHub/EldenRing-GraphRAG/data_input/items.json'
df = pd.read_json(path)
df.head()
df.drop(columns=['id', 'image', 'description', 'type', 'obtainedFrom'], inplace=True)
df.dropna(inplace=True)

# %%
path = '/Users/user/Documents/GitHub/EldenRing-GraphRAG/data_input/shields.json'
df = pd.read_json(path)
df.head()
df.drop(columns=['id', 'image', 'attack', 'defence', 'scalesWith', 'requiredAttributes', 'category', 'weight'], inplace=True)
df.dropna(inplace=True)

# %%
path = '/Users/user/Documents/GitHub/EldenRing-GraphRAG/data_input/sorceries.json'
df = pd.read_json(path)
df.head()
df.drop(columns=['id', 'image', 'type', 'cost', 'slots', 'requires'], inplace=True)
df.dropna(inplace=True)

# %%
path = '/Users/user/Documents/GitHub/EldenRing-GraphRAG/data_input/spirits.json'
df = pd.read_json(path)
df.head()
df.drop(columns=['id', 'image', 'fpCost', 'hpCost', 'effect'], inplace=True)
df.dropna(inplace=True)

# %%
path = '/Users/user/Documents/GitHub/EldenRing-GraphRAG/data_input/talismans.json'
df = pd.read_json(path)
df.head()
df.drop(columns=['id', 'image'], inplace=True)
df.dropna(inplace=True)

# %%
path = '/Users/user/Documents/GitHub/EldenRing-GraphRAG/data_input/weapons.json'
df = pd.read_json(path)
df.head()
df.drop(columns=['id', 'image', 'attack', 'defence', 'scalesWith', 'requiredAttributes', 'category', 'weight'], inplace=True)
df.dropna(inplace=True)

# %%
output_file = 'weapons.txt'

# Write DataFrame to text file
with open(output_file, 'w') as file:
    file.write(df.to_csv(index=False))  # index=False omits row numbers

# %%
# Function to merge all text files in a folder into one file
def merge_text_files(folder_path, output_file):
    with open(output_file, 'w') as outfile:
        # Loop through all files in the folder
        for filename in os.listdir(folder_path):
            # Check if the file has a .txt extension
            if filename.endswith('.txt'):
                file_path = os.path.join(folder_path, filename)
                with open(file_path, 'r') as infile:
                    contents = infile.read()
                    # Write the contents of each text file to the output file
                    outfile.write(contents + '\n')  # Add a newline after each file's content

    print(f"All text files have been merged into {output_file}")

# %%
folder_path = "/Users/user/Documents/GitHub/EldenRing-GraphRAG/data_input/txt"  # Replace with your folder path
output_file = "merged_output.txt"    # The file to save the merged content
merge_text_files(folder_path, output_file)
# Out:
# All text files have been merged into merged_output.txt
