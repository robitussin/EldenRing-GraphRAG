# %%
import pandas as pd
import datasets
from datasets import Dataset, load_dataset
from knowledge_graph_maker import Neo4jGraphModel

# %% [markdown]
# ### WikiQA

# %%
splits = {'test': 'data/test-00000-of-00001.parquet', 'validation': 'data/validation-00000-of-00001.parquet', 'train': 'data/train-00000-of-00001.parquet'}
df_wikiqa = pd.read_parquet("hf://datasets/microsoft/wiki_qa/" + splits["test"])

# %%
df_wikiqa.info()

# %%
df_wikiqa.sample(10)

# %% [markdown]
# ### SQuAD

# %%
splits = {'train': 'plain_text/train-00000-of-00001.parquet', 'validation': 'plain_text/validation-00000-of-00001.parquet'}
df_squad = pd.read_parquet("hf://datasets/rajpurkar/squad/" + splits["train"])

# %%
df.info()

# %%
df_squad.sample(10)

# %%
print("Context:", df_squad.iloc[32465]['context'])
print("Question:", df_squad.iloc[32465]['question'])
print("Answer:", df_squad.iloc[32465]['answers'])

# %% [markdown]
# ### NarrativeQA

# %%
ds_narrativeqa = load_dataset("deepmind/narrativeqa")
ds_narrativeqa
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['document', 'question', 'answers'],
#         num_rows: 32747
#     })
#     test: Dataset({
#         features: ['document', 'question', 'answers'],
#         num_rows: 10557
#     })
#     validation: Dataset({
#         features: ['document', 'question', 'answers'],
#         num_rows: 3461
#     })
# })

# %%
x = ds_narrativeqa['test']
type(x)
# Out:
# datasets.arrow_dataset.Dataset

# %%
df = pd.DataFrame(x)

# %%
print(df.iloc[0]['document']['text'])
print(df.iloc[0]['document']['summary']['text'])
print(df.iloc[0]['question']['text'])
print(df.iloc[0]['answers'][0]['text'])

essay = df.iloc[0]['document']['text']
# Out:
# <html><title>Pump Up The Volume Transcript</title><pre>
# Happy Harry Hardon - Did you ever get the feeling that everything in America is
# completely fucked up. You know that feeling that the whole country is like one inch
# away from saying 'That's it, forget it.' You think about it. Everything is polluted. The
# environment, the government, the schools you name it. Speaking of schools. I was
# walking the households the other day and I asked myself. Is there live after high school?
# Because I can't face tomorrow, let alone a whole year of this shit. Yeah, you got it folks.
# It's me again with a little attitude for all you out here and waiting for Atlanta. All you
# nice people living in the middle of America the beautiful. Lets see, we're on er 92 FM
# tonight and it feels like a nice clean little band so far. No one else is using it. The price is
# right. Heh, heh. And yes folks you guest it. Tonight I am as horny as a ten peckerd house,
# ...

# %% [markdown]
# ### QASPER

# %%
ds_qasper = load_dataset("allenai/qasper")

# %% [markdown]
# ### Cinderella

# %%
with open('./data_input/txt/cinderella.txt') as file:
    essay = file.read()

# %% [markdown]
# ### TEST PIPELINE

# %%
from generate_graph import get_propositions, generate

# %%
propositions = get_propositions(essay)
# Out:
# /Users/user/miniconda3/envs/graphmaker/lib/python3.11/site-packages/langchain/hub.py:86: DeprecationWarning: The `langchainhub sdk` is deprecated.
# Please use the `langsmith sdk` instead:
#   pip install langsmith
# Use the `pull_prompt` method.
#   res_dict = client.pull_repo(owner_repo_commit)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 propositions = get_propositions(essay)
#
# File ~/Documents/GitHub/EldenRing-GraphRAG/generate_graph.py:46, in get_propositions(text)
#      43 proposition_list = []
#      45 for t in text:
# ---> 46     runnable_output = runnable.invoke({
#      47         "input": text
#      48     }).content
#      50     propositions = structured_llm.invoke(runnable_output).sentences
#      51     proposition_list.append(propositions)
#
# ...

# %%
propositions
# Out:
# ['The wife of a rich man fell sick.',
#  'The wife of a rich man felt that her end was drawing near.',
#  'The wife of a rich man called her only daughter to her bedside.',
#  "The wife of a rich man said to her daughter, 'Dear child, be good and pious.'",
#  'The wife of a rich man said that then the good God will always protect her daughter.',
#  'The wife of a rich man said that she will look down on her daughter from heaven and be near her.',
#  'The wife of a rich man closed her eyes and departed.',
#  "Every day the maiden went out to her mother's grave.",
#  "The maiden wept at her mother's grave.",
#  'The maiden remained pious and good.',
#  'When winter came, the snow spread a white sheet over the grave.',
#  'By the time the spring sun had drawn the snow off again, the rich man had taken another wife.',
#  'The new wife had brought with her into the house two daughters.',
#  'The two daughters were beautiful and fair of face.',
# ...

# %%
propositions = ['The wife of a rich man fell sick.',
  'The wife of a rich man felt that her end was drawing near.',
  'The wife of a rich man called her only daughter to her bedside.',
  "The wife of a rich man said to her daughter, 'Dear child, be good and pious.'",
  'The wife of a rich man said that then the good God will always protect her daughter.',
  'The wife of a rich man said that she will look down on her daughter from heaven and be near her.',
  'The wife of a rich man closed her eyes and departed.',
  "Every day the maiden went out to her mother's grave.",
  "The maiden wept at her mother's grave.",
  'The maiden remained pious and good.',
  'When winter came, the snow spread a white sheet over the grave.',
  'By the time the spring sun had drawn the snow off again, the rich man had taken another wife.',
  'The new wife had brought with her into the house two daughters.',
  'The two daughters were beautiful and fair of face.',
  'The two daughters were vile and black of heart.',
  'A bad time began for the poor step-child.',
  "The two daughters mocked the poor step-child, saying, 'Is the stupid goose to sit in the parlor with us?'",
  "The two daughters said, 'He who wants to eat bread must earn it.'",
  "The two daughters said, 'Out with the kitchen-wench.'",
  "The two daughters took the poor step-child's pretty clothes away from her.",
  'The two daughters put an old grey bedgown on the poor step-child.',
  'The two daughters gave the poor step-child wooden shoes.',
  "The two daughters laughed at the poor step-child, saying, 'Just look at the proud princess, how decked out she is.'",
  'The two daughters led the poor step-child into the kitchen.',
  'The poor step-child had to do hard work from morning till night.',
  'The poor step-child had to get up before daybreak.',
  'The poor step-child had to carry water, light fires, cook, and wash.',
  'The sisters did her every imaginable injury.',
  'The sisters mocked the poor step-child.',
  'The sisters emptied her peas and lentils into the ashes.',
  'The poor step-child was forced to sit and pick the peas and lentils out again.',
  'In the evening, when the poor step-child had worked till she was weary, she had no bed to go to.',
  'The poor step-child had to sleep by the hearth in the cinders.',
  'The poor step-child always looked dusty and dirty.',
  'The sisters called the poor step-child Cinderella.',
  'The father was once going to the fair.',
  'The father asked his two step-daughters what he should bring back for them.',
  "One step-daughter said, 'Beautiful dresses.'",
  "The second step-daughter said, 'Pearls and jewels.'",
  'The father asked Cinderella what she would like.',
  "Cinderella said, 'Father, break off for me the first branch which knocks against your hat on your way home.'",
  'The father bought beautiful dresses, pearls, and jewels for his two step-daughters.',
  'On his way home, a hazel twig brushed against him and knocked off his hat.',
  'The father broke off the branch and took it with him.',
  'When the father reached home, he gave his step-daughters the things which they had wished for.',
  'To Cinderella, the father gave the branch from the hazel-bush.',
  'Cinderella thanked her father.',
  "Cinderella went to her mother's grave and planted the branch on it.",
  'Cinderella wept so much that her tears fell down on the branch and watered it.',
  'The branch grew and became a handsome tree.',
  'Thrice a day, Cinderella went and sat beneath the tree.',
  'Cinderella wept and prayed beneath the tree.',
  'A little white bird always came on the tree.',
  'If Cinderella expressed a wish, the bird threw down to her what she had wished for.',
  'The king gave orders for a festival which was to last three days.',
  'All the beautiful young girls in the country were invited to the festival.',
  "The festival was held so that the king's son might choose himself a bride.",
  'When the two step-sisters heard that they too were to appear among the number, they were delighted.',
  "The two step-sisters called Cinderella and said, 'Comb our hair for us, brush our shoes and fasten our buckles, for we are going to the wedding at the king's palace.'",
  'Cinderella obeyed but wept.',
  'Cinderella wept because she too would have liked to go with them to the dance.',
  'Cinderella begged her step-mother to allow her to go to the festival.',
  "The step-mother said to Cinderella, 'You go, Cinderella, covered in dust and dirt as you are, and would go to the festival.'",
  'The step-mother said that Cinderella had no clothes and shoes, and yet would dance.',
  "As Cinderella continued asking, the step-mother said at last, 'I have emptied a dish of lentils into the ashes for you, if you have picked them out again in two hours, you shall go with us.'",
  'Cinderella went through the back-door into the garden.',
  "Cinderella called, 'You tame pigeons, you turtle-doves, and all you birds beneath the sky, come and help me to pick the good into the pot, the bad into the crop.'",
  'Two white pigeons came in by the kitchen window.',
  'Afterwards, the turtle-doves came.',
  'At last, all the birds beneath the sky came whirring and crowding in.',
  'The birds alighted amongst the ashes.',
  'The pigeons nodded with their heads and began to pick.',
  'The rest of the birds began to pick and gathered all the good grains into the dish.',
  'Hardly had one hour passed before the birds had finished.',
  'The birds flew out again.',
  'Cinderella took the dish to her step-mother and was glad.',
  'Cinderella believed that now she would be allowed to go with them to the festival.',
  "The step-mother said, 'No, Cinderella, you have no clothes and you cannot dance.'",
  'The step-mother said that Cinderella would only be laughed at.',
  "As Cinderella wept at this, the step-mother said, 'If you can pick two dishes of lentils out of the ashes for me in one hour, you shall go with us.'",
  'The step-mother thought that Cinderella most certainly cannot do it again.',
  'When the step-mother had emptied the two dishes of lentils amongst the ashes, Cinderella went through the back-door into the garden.',
  "Cinderella cried, 'You tame pigeons, you turtle-doves, and all you birds beneath the sky, come and help me to pick the good into the pot, the bad into the crop.'",
  'Two white pigeons came in by the kitchen window.',
  'Afterwards, the turtle-doves came.',
  'At length, all the birds beneath the sky came whirring and crowding in.',
  'The birds alighted amongst the ashes.',
  'The doves nodded with their heads and began to pick.',
  'The others began to pick and gathered all the good seeds into the dishes.',
  'Before half an hour was over, the birds had already finished.',
  'The birds flew out again.',
  'Cinderella was delighted and believed that she might now go with them to the wedding.',
  "The step-mother said, 'All this will not help.'",
  'The step-mother said that Cinderella could not go with them because she had no clothes and could not dance.',
  'The step-mother said that they should be ashamed of Cinderella.',
  'The step-mother turned her back on Cinderella and hurried away with her two proud daughters.',
  "As no one was now at home, Cinderella went to her mother's grave beneath the hazel-tree.",
  "Cinderella cried, 'Shiver and quiver, little tree, silver and gold throw down over me.'",
  'The bird threw a gold and silver dress down to Cinderella.',
  'The bird threw slippers embroidered with silk and silver down to Cinderella.',
  'Cinderella put on the dress with all speed.',
  'Cinderella went to the wedding.',
  "Cinderella's step-sisters and step-mother did not know her.",
  "Cinderella's step-sisters and step-mother thought she must be a foreign princess.",
  'Cinderella looked so beautiful in the golden dress.',
  "Cinderella's step-sisters never once thought of her.",
  "Cinderella's step-sisters believed that she was sitting at home in the dirt, picking lentils out of the ashes.",
  'The prince approached Cinderella.',
  'The prince took Cinderella by the hand and danced with her.',
  'The prince would dance with no other maiden.',
  "The prince never let loose of Cinderella's hand.",
  "If anyone else came to invite Cinderella, the prince said, 'This is my partner.'",
  'Cinderella danced till it was evening.',
  'Cinderella wanted to go home.',
  "The king's son said, 'I will go with you and bear you company.'",
  "The king's son wished to see to whom the beautiful maiden belonged.",
  'Cinderella escaped from him and sprang into the pigeon-house.',
  "The king's son waited until Cinderella's father came.",
  "The king's son told Cinderella's father that the unknown maiden had leapt into the pigeon-house.",
  "Cinderella's father thought, 'Can it be Cinderella?'",
  "Cinderella's father had to bring him an axe and a pickaxe to hew the pigeon-house to pieces.",
  'No one was inside the pigeon-house.',
  'When they got home, Cinderella lay in her dirty clothes among the ashes.',
  'A dim little oil-lamp was burning on the mantle-piece.',
  'Cinderella had jumped quickly down from the back of the pigeon-house.',
  'Cinderella had run to the little hazel-tree.',
  'Cinderella had taken off her beautiful clothes and laid them on the grave.',
  "The bird had taken Cinderella's beautiful clothes away again.",
  'Cinderella seated herself in the kitchen amongst the ashes in her grey gown.',
  "The next day when the festival began afresh, Cinderella's parents and step-sisters had gone once more.",
  "Cinderella went to the hazel-tree and said, 'Shiver and quiver, my little tree, silver and gold throw down over me.'",
  'The bird threw down a much more beautiful dress than on the preceding day.',
  'When Cinderella appeared at the wedding in this dress, everyone was astonished at her beauty.',
  "The king's son had waited until Cinderella came.",
  "The king's son instantly took Cinderella by the hand and danced with no one but her.",
  "When others came and invited Cinderella, the king's son said, 'This is my partner.'",
  'When evening came, Cinderella wished to leave.',
  "The king's son followed Cinderella and wanted to see into which house she went.",
  'Cinderella sprang away from him and into the garden behind the house.',
  'In the garden stood a beautiful tall tree on which hung the most magnificent pears.',
  'Cinderella clambered so nimbly between the branches like a squirrel.',
  "The king's son did not know where Cinderella had gone.",
  "The king's son waited until Cinderella's father came.",
  "The king's son said to Cinderella's father that the unknown maiden had escaped from him and that he believed she had climbed up the pear-tree.",
  "Cinderella's father thought, 'Can it be Cinderella?'",
  "Cinderella's father had an axe brought and cut the tree down.",
  'No one was on the tree.',
  'When they got into the kitchen, Cinderella lay there among the ashes, as usual.',
  'Cinderella had jumped down on the other side of the tree.',
  'Cinderella had taken the beautiful dress to the bird on the little hazel-tree.',
  'Cinderella had put on her grey gown.',
  "On the third day, when Cinderella's parents and sisters had gone away, Cinderella went once more to her mother's grave.",
  "Cinderella said to the little tree, 'Shiver and quiver, my little tree, silver and gold throw down over me.'",
  'The bird threw down to Cinderella a dress which was more splendid and magnificent than any she had yet had.',
  'The slippers were golden.',
  'When Cinderella went to the festival in the dress, no one knew how to speak for astonishment.',
  "The king's son danced with Cinderella only.",
  "If anyone invited Cinderella to dance, the king's son said, 'This is my partner.'",
  'When evening came, Cinderella wished to leave.',
  "The king's son was anxious to go with her.",
  'Cinderella escaped from him so quickly that he could not follow her.',
  "The king's son had employed a ruse.",
  "The king's son had caused the whole staircase to be smeared with pitch.",
  "When Cinderella ran down, the maiden's left slipper remained stuck.",
  "The king's son picked up the slipper.",
  'The slipper was small and dainty, and all golden.',
  "The next morning, the king's son went with the slipper to Cinderella's father.",
  "The king's son said to Cinderella's father, 'No one shall be my wife but she whose foot this golden slipper fits.'",
  'The two sisters were glad because they had pretty feet.',
  'The eldest sister went with the shoe into her room and wanted to try it on.',
  "The eldest sister's mother stood by.",
  'The eldest sister could not get her big toe into the shoe.',
  'The shoe was too small for the eldest sister.',
  "The mother gave the eldest sister a knife and said, 'Cut the toe off, when you are queen you will have no more need to go on foot.'",
  'The eldest sister cut the toe off.',
  'The eldest sister forced her foot into the shoe.',
  "The eldest sister swallowed the pain and went out to the king's son.",
  "The king's son took the eldest sister on his horse as his bride and rode away with her.",
  'They were obliged, however, to pass the grave.',
  "There, on the hazel-tree, sat the two pigeons and cried, 'Turn and peep, turn and peep, there's blood within the shoe, the shoe it is too small for her, the true bride waits for you.'",
  "The king's son looked at the eldest sister's foot and saw how the blood was trickling from it.",
  "The king's son turned his horse round and took the false bride home again.",
  "The king's son said that the eldest sister was not the true one.",
  "The king's son said that the other sister was to put the shoe on.",
  'The other sister went into her chamber and got her toes safely into the shoe.',
  "The other sister's heel was too large.",
  "The mother gave the other sister a knife and said, 'Cut a bit off your heel, when you are queen you will have no more need to go on foot.'",
  'The other sister cut a bit off her heel.',
  'The other sister forced her foot into the shoe.',
  "The other sister swallowed the pain and went out to the king's son.",
  "The king's son took the other sister on his horse as his bride and rode away with her.",
  "When they passed by the hazel-tree, the two pigeons sat on it and cried, 'Turn and peep, turn and peep, there's blood within the shoe, the shoe it is too small for her, the true bride waits for you.'",
  "The king's son looked down at the other sister's foot and saw how the blood was running out of her shoe.",
  "The king's son saw how the blood had stained the other sister's white stocking quite red.",
  "The king's son turned his horse and took the false bride home again.",
  "The king's son said that this also is not the right one.",
  "The king's son asked if Cinderella's father had no other daughter.",
  "Cinderella's father said that there was still a little stunted kitchen-wench which his late wife left behind her.",
  "Cinderella's father said that Cinderella could not possibly be the bride.",
  "The king's son said he was to send Cinderella up to him.",
  "Cinderella's mother answered that Cinderella was much too dirty and could not show herself.",
  "The king's son absolutely insisted on it.",
  'Cinderella had to be called.',
  'Cinderella first washed her hands and face clean.',
  "Cinderella went and bowed down before the king's son.",
  "The king's son gave Cinderella the golden shoe.",
  'Cinderella seated herself on a stool.',
  'Cinderella drew her foot out of the heavy wooden shoe.',
  'Cinderella put her foot into the slipper, which fitted like a glove.',
  "When Cinderella rose up, the king's son looked at her face.",
  "The king's son recognized the beautiful maiden who had danced with him.",
  "The king's son cried, 'That is the true bride.'",
  'The step-mother and the two sisters were horrified.',
  'The step-mother and the two sisters became pale with rage.',
  "The king's son took Cinderella on his horse and rode away with her.",
  "As they passed by the hazel-tree, the two white doves cried, 'Turn and peep, turn and peep, no blood is in the shoe, the shoe is not too small for her, the true bride rides with you.'",
  "When the two doves cried that, they came flying down and placed themselves on Cinderella's shoulders, one on the right, the other on the left, and remained sitting there.",
  "When the wedding with the king's son was to be celebrated, the two false sisters came.",
  'The two false sisters wanted to get into favor with Cinderella and share her good fortune.',
  'When the betrothed couple went to church, the elder sister was at the right side and the younger sister at the left.',
  'The pigeons pecked out one eye from each of the two false sisters.',
  'Afterwards, as they came back, the elder sister was at the left and the younger sister at the right.',
  'The pigeons pecked out the other eye from each of the two false sisters.',
  'The two false sisters were punished with blindness all their days for their wickedness and falsehood.']

# %%
if generate(propositions):
    print("Sucess")
else:
    print("Failed")
# Out:
# Using Model:  gpt-4o-mini
# Using Model:  gpt-4o-mini
# Using Model:  gpt-4o-mini
# Using Model:  gpt-4o-mini
# Using Model:  gpt-4o-mini
# Using Model:  gpt-4o-mini
# Using Model:  gpt-4o-mini
# Using Model:  gpt-4o-mini
# Using Model:  gpt-4o-mini
# Using Model:  gpt-4o-mini
# Using Model:  gpt-4o-mini
# Using Model:  gpt-4o-mini
# Using Model:  gpt-4o-mini
# Using Model:  gpt-4o-mini
# Using Model:  gpt-4o-mini
# Using Model:  gpt-4o-mini
# Using Model:  gpt-4o-mini
# Using Model:  gpt-4o-mini
# Using Model:  gpt-4o-mini
# Using Model:  gpt-4o-mini
# Using Model:  gpt-4o-mini
# Using Model:  gpt-4o-mini
# Using Model:  gpt-4o-mini
# Using Model:  gpt-4o-mini
# Using Model:  gpt-4o-mini
# Using Model:  gpt-4o-mini
# Using Model:  gpt-4o-mini
# Using Model:  gpt-4o-mini
# Using Model:  gpt-4o-mini
# Using Model:  gpt-4o-mini
# Using Model:  gpt-4o-mini
# Using Model:  gpt-4o-mini
# Using Model:  gpt-4o-mini
# Using Model:  gpt-4o-mini
# Using Model:  gpt-4o-mini
# ...
